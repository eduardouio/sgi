MA20200360,094-20,HLCULIV200511293
MA20200361,099-20,HLCULIV200511311
MA20200369,101-20,HLCULIV200529711
MA20200387,107-20,SUDUROLEH005250X
MA20200387,107-20,SUDUROLEH005250X
MA20200387,107-20,SUDUROLEH005250X
MA20200390,103-20,HLCULIV200538006
MA20200390,103-20,HLCULIV200538006'''

# %%
lines = x.splitlines()
all_items = []
idx = set()
uniques = []
for l in lines:
    item = l.split(',')
    idx.add(item[0])
    all_items.append(item)


for i in idx:
    for li in all_items:
        if li[0] == i :
            uniques.append(li)
            break

sql = ''

for item in uniques:
    line_sql = "update pedido set nro_matricula = '{}', nro_bl='{}' where nro_pedido = '{}';".format(
        item[0],item[2],item[1]
    )
    #print(line_sql)


matriculas = ['MA20190329','MA20190431','MA20190442','MA20190446','MA20190452','MA20190453','MA20190454',
'MA20190456','MA20190460','MA20190461','MA20190466','MA20190540','MA20190541','MA20190543',
'MA20190546','MA20190547','MA20190548','MA20190549','MA20190552','MA20190553','MA20190555',
'MA20190556','MA20190599','MA20190608','MA20190680','MA20190682','MA20200037','MA20200067',
'MA20200069','MA20200099','MA20200100','MA20200105','MA20200186','MA20200187','MA20200188',
'MA20200191','MA20200192','MA20200200','MA20200201','MA20200202','MA20200203','MA20200204',
'MA20200205','MA20200206','MA20200207','MA20200208','MA20200209','MA20200210','MA20200211',
'MA20200369']

for
# Out:
# update pedido set nro_matricula = 'MA20200094', nro_bl='HLCULIV200125499' where nro_pedido = '025-20';
# update pedido set nro_matricula = 'MA20190461', nro_bl='BQEGCLS192764' where nro_pedido = '220-19';
# update pedido set nro_matricula = 'MA20200353', nro_bl='HLCULIV200511250' where nro_pedido = '097-20';
# update pedido set nro_matricula = 'MA20200211', nro_bl='HLCULIV200322716' where nro_pedido = '058-20';
# update pedido set nro_matricula = 'MA20190315', nro_bl='EMFCL-102590' where nro_pedido = '104-19';
# update pedido set nro_matricula = 'MA20200187', nro_bl='HLCULIV200311655' where nro_pedido = '071-20';
# update pedido set nro_matricula = 'MA20200097', nro_bl='HLCULIV200125601' where nro_pedido = '021-20';
# update pedido set nro_matricula = 'MA20190569', nro_bl='0050928' where nro_pedido = '314-19';
# update pedido set nro_matricula = 'MA20200359', nro_bl='HLCULIV200511271' where nro_pedido = '095-20';
# update pedido set nro_matricula = 'MA20200216', nro_bl='HLCULIV200311582' where nro_pedido = '069-20';
# update pedido set nro_matricula = 'MA20200096', nro_bl='HLCULIV200110360' where nro_pedido = '014-20';
# update pedido set nro_matricula = 'MA20190574', nro_bl='HLCULIV190924608' where nro_pedido = '331-19';
# update pedido set nro_matricula = 'MA20190362', nro_bl='BQEGCLS190794' where nro_pedido = '147-19';
# update pedido set nro_matricula = 'MA20200158', nro_bl='HLCULIV200128475' where nro_pedido = '047-20';
# update pedido set nro_matricula = 'MA20190453', nro_bl='HLCULIV190753378' where nro_pedido = '179-19';
# update pedido set nro_matricula = 'MA20190599', nro_bl='EM1-R19115' where nro_pedido = '327-19';
# update pedido set nro_matricula = 'MA20200148', nro_bl='HLCULIV200128632' where nro_pedido = '042-20';
# update pedido set nro_matricula = 'MA20200032', nro_bl='1519294' where nro_pedido = '312-19';
# update pedido set nro_matricula = 'MA20190329', nro_bl='BQEGCLS188687' where nro_pedido = '131-19';
# update pedido set nro_matricula = 'MA20200099', nro_bl='HLCULIV200110499' where nro_pedido = '016-20';
# update pedido set nro_matricula = 'MA20190490', nro_bl='BQEGCLS193216' where nro_pedido = '326-19';
# update pedido set nro_matricula = 'MA20190549', nro_bl='BQEGCLS194392' where nro_pedido = '268-19';
# update pedido set nro_matricula = 'MA20190507', nro_bl='BQEGCLS193546' where nro_pedido = '217-19';
# update pedido set nro_matricula = 'MA20190617', nro_bl='BQEGCLS196052' where nro_pedido = '356-19';
# update pedido set nro_matricula = 'MA20200100', nro_bl='HLCULIV200330315' where nro_pedido = '026-20';
# update pedido set nro_matricula = 'MA20200182', nro_bl='HLCULIV200322676' where nro_pedido = '061-20';
# update pedido set nro_matricula = 'MA20190540', nro_bl='BQEGCLS194398' where nro_pedido = '261-19';
# update pedido set nro_matricula = 'MA20200162', nro_bl='HLCULIV200128431' where nro_pedido = '048-20';
# update pedido set nro_matricula = 'MA20200138', nro_bl='HLCULIV200128560' where nro_pedido = '045-20';
# update pedido set nro_matricula = 'MA20190630', nro_bl='BQEGCLS196050' where nro_pedido = '281-19 Y 354-19';
# update pedido set nro_matricula = 'MA20200127', nro_bl='HLCULIV200127808' where nro_pedido = '056-20';
# update pedido set nro_matricula = 'MA20200141', nro_bl='HLCULIV200128698' where nro_pedido = '039-20';
# update pedido set nro_matricula = 'MA20190595', nro_bl='BQEGCLS195688' where nro_pedido = '267-19';
# update pedido set nro_matricula = 'MA20190693', nro_bl='BQEGCLS197502' where nro_pedido = '362-19';
# update pedido set nro_matricula = 'MA20190577', nro_bl='BQEGCLS195198' where nro_pedido = '259-19';
# update pedido set nro_matricula = 'MA20200209', nro_bl='HLCULIV200311611' where nro_pedido = '067-20';
# update pedido set nro_matricula = 'MA20200130', nro_bl='HLCULIV200128738' where nro_pedido = '036-20';
# update pedido set nro_matricula = 'MA20200147', nro_bl='HLCULIV200128782' where nro_pedido = '033-20';
# update pedido set nro_matricula = 'MA20190582', nro_bl='HLCULIV190924580' where nro_pedido = '334-19';
# update pedido set nro_matricula = 'MA20200360', nro_bl='HLCULIV200511293' where nro_pedido = '094-20';
# update pedido set nro_matricula = 'MA20190626', nro_bl='BQEGARM061291' where nro_pedido = '257-19';
# update pedido set nro_matricula = 'MA20190419', nro_bl='BQEGCLS191954' where nro_pedido = '158-19';
# update pedido set nro_matricula = 'MA20200183', nro_bl='HLCULIV200311677' where nro_pedido = '073-20';
# update pedido set nro_matricula = 'MA20200139', nro_bl='HLCULIV200250120' where nro_pedido = '028-20';
# update pedido set nro_matricula = 'MA20190541', nro_bl='BQEGCLS194400' where nro_pedido = '253-19';
# update pedido set nro_matricula = 'MA20190572', nro_bl='HLCULIV190924334' where nro_pedido = '332-19';
# update pedido set nro_matricula = 'MA20200204', nro_bl='HLCULIV200311600' where nro_pedido = '070-20';
# update pedido set nro_matricula = 'MA20200202', nro_bl='HLCULIV200128380' where nro_pedido = '050-20';
# update pedido set nro_matricula = 'MA20190616', nro_bl='BQEGCLS196053' where nro_pedido = '357-19';
# update pedido set nro_matricula = 'MA20200120', nro_bl='HLCULIV200110316' where nro_pedido = '012-20';
# update pedido set nro_matricula = 'MA20200169', nro_bl='HLCULIV2001288800' where nro_pedido = '032-20';
# update pedido set nro_matricula = 'MA20200125', nro_bl='HLVULIV200158240' where nro_pedido = '054-20';
# update pedido set nro_matricula = 'MA20190460', nro_bl='BQEGCLS192732' where nro_pedido = '211-19';
# update pedido set nro_matricula = 'MA20200234', nro_bl='HLCULIV200322750' where nro_pedido = '057-20';
# update pedido set nro_matricula = 'MA20200200', nro_bl='HLCULIV200311728' where nro_pedido = '066-20';
# update pedido set nro_matricula = 'MA20190555', nro_bl='BQEGARM060657' where nro_pedido = '323-19';
# update pedido set nro_matricula = 'MA20200191', nro_bl='HLCULIV200313723' where nro_pedido = '079-20';
# update pedido set nro_matricula = 'MA20190559', nro_bl='BQEGCLS194367' where nro_pedido = '256-19 329-19';
# update pedido set nro_matricula = 'MA20200206', nro_bl='HLCULIV200311750' where nro_pedido = '076-20';
# update pedido set nro_matricula = 'MA20190517', nro_bl='BQEGARM060272' where nro_pedido = '320-19';
# update pedido set nro_matricula = 'MA20200106', nro_bl='HLCULIV200158251' where nro_pedido = '053-20';
# update pedido set nro_matricula = 'MA20200177', nro_bl='HLCULIV200311761' where nro_pedido = '063-20';
# update pedido set nro_matricula = 'MA20190635', nro_bl='BQEGARM061292' where nro_pedido = '258-19';
# update pedido set nro_matricula = 'MA20200159', nro_bl='HLCULIV200128654' where nro_pedido = '041-20';
# update pedido set nro_matricula = 'MA20200246', nro_bl='HLCUDUB200208400' where nro_pedido = '092-20';
# update pedido set nro_matricula = 'MA20200144', nro_bl='HLCULIV200128687' where nro_pedido = '040-20';
# update pedido set nro_matricula = 'MA20200192', nro_bl='HLCULIV200311593' where nro_pedido = '084-20';
# update pedido set nro_matricula = 'MA20200208', nro_bl='HLCULIV200305057' where nro_pedido = '060-20';
# update pedido set nro_matricula = 'MA20200188', nro_bl='HLCULIV200311644' where nro_pedido = '064-20';
# update pedido set nro_matricula = 'MA20190589', nro_bl='10-1910-0980' where nro_pedido = '310-19';
# update pedido set nro_matricula = 'MA20200207', nro_bl='HLCULIV200311739' where nro_pedido = '062-20';
# update pedido set nro_matricula = 'MA20190482', nro_bl='EMFCL-103312' where nro_pedido = '149-19';
# update pedido set nro_matricula = 'MA20190583', nro_bl='10-1909-0944' where nro_pedido = '308-19';
# update pedido set nro_matricula = 'MA20200178', nro_bl='HLCULIV200313387' where nro_pedido = '074-20';
# update pedido set nro_matricula = 'MA20190573', nro_bl='50925' where nro_pedido = '148-19';
# update pedido set nro_matricula = 'MA20200348', nro_bl='HLVULIV200515619' where nro_pedido = '105-20';
# update pedido set nro_matricula = 'MA20190680', nro_bl='HLCULIV191016680' where nro_pedido = '352-19';
# update pedido set nro_matricula = 'MA20190632', nro_bl='822019090361' where nro_pedido = '316-19';
# update pedido set nro_matricula = 'MA20200230', nro_bl='20-0076PCH' where nro_pedido = '090-20';
# update pedido set nro_matricula = 'MA20200361', nro_bl='HLCULIV200511311' where nro_pedido = '099-20';
# update pedido set nro_matricula = 'MA20200145', nro_bl='HLCULIV200126988' where nro_pedido = '027-20';
# update pedido set nro_matricula = 'MA20200247', nro_bl='HLCULIV200343481' where nro_pedido = '078-20';
# update pedido set nro_matricula = 'MA20190392', nro_bl='BQEGCLS191655' where nro_pedido = '146-19';
# update pedido set nro_matricula = 'MA20200107', nro_bl='HLCULIV200111118' where nro_pedido = '017-20';
# update pedido set nro_matricula = 'MA20200108', nro_bl='HLCULIV200125540' where nro_pedido = '020-20';
# update pedido set nro_matricula = 'MA20200160', nro_bl='HLCULIV200128410' where nro_pedido = '049-20';
# update pedido set nro_matricula = 'MA20200210', nro_bl='HLCULIV200313471' where nro_pedido = '080-20';
# update pedido set nro_matricula = 'MA20190492', nro_bl='BQEGCLS193217' where nro_pedido = '226-19';
# update pedido set nro_matricula = 'MA20200089', nro_bl='HLCULIV200110517' where nro_pedido = '018-20';
# update pedido set nro_matricula = 'MA20190456', nro_bl='GTG0257069' where nro_pedido = '319-19';
# update pedido set nro_matricula = 'MA20200352', nro_bl='HLCULIV200511333' where nro_pedido = '096-20';
# update pedido set nro_matricula = 'MA20200369', nro_bl='HLCULIV200529711' where nro_pedido = '101-20';
# update pedido set nro_matricula = 'MA20190382', nro_bl='EMFCL-102759' where nro_pedido = '110-19';
# update pedido set nro_matricula = 'MA20200175', nro_bl='HLCULIV200304836' where nro_pedido = '082-20';
# update pedido set nro_matricula = 'MA20190732', nro_bl='SUDUA9GDY003575X' where nro_pedido = '390-19';
# update pedido set nro_matricula = 'MA20200121', nro_bl='HLCULIV200111089' where nro_pedido = '004-20';
# update pedido set nro_matricula = 'MA20200077', nro_bl='HLCULIV200110583' where nro_pedido = '013-20';
# update pedido set nro_matricula = 'MA20200358', nro_bl='HLCULIV200511260' where nro_pedido = '098-20';
# update pedido set nro_matricula = 'MA20190581', nro_bl='10-1909-0983' where nro_pedido = '309-19';
# update pedido set nro_matricula = 'MA20190431', nro_bl='HLCULIV190756577' where nro_pedido = '181-19';
# update pedido set nro_matricula = 'MA20190480', nro_bl='BQEGCLS192762' where nro_pedido = '224-19';
# update pedido set nro_matricula = 'MA20200157', nro_bl='HLCULIV200128771' where nro_pedido = '034-20';
# update pedido set nro_matricula = 'MA20200351', nro_bl='HLCULIV200520487' where nro_pedido = '102-20';
# update pedido set nro_matricula = 'MA20200326', nro_bl='GTG0273471' where nro_pedido = '104-20';
# update pedido set nro_matricula = 'MA20190454', nro_bl='HLCULIV190753301' where nro_pedido = '189-19';
# update pedido set nro_matricula = 'MA20200149', nro_bl='HLCULIV200128486' where nro_pedido = '046-20';
# update pedido set nro_matricula = 'MA20200140', nro_bl='HLCULIV200128750' where nro_pedido = '035-20';
# update pedido set nro_matricula = 'MA20190692', nro_bl='BQEGCLS197500' where nro_pedido = '363-19';
# update pedido set nro_matricula = 'MA20200261', nro_bl='HLCULIV200365625' where nro_pedido = '024-20';
# update pedido set nro_matricula = 'MA20190547', nro_bl='BQEGCLS194407' where nro_pedido = '263-19';
# update pedido set nro_matricula = 'MA20190552', nro_bl='BQEGCLS194426' where nro_pedido = '254-19';
# update pedido set nro_matricula = 'MA20200349', nro_bl='HLCULIV200518186' where nro_pedido = '100-20';
# update pedido set nro_matricula = 'MA20190608', nro_bl='HLCULIV190942883' where nro_pedido = '335-19';
# update pedido set nro_matricula = 'MA20190498', nro_bl='BQEGCLS193314' where nro_pedido = '222-19';
# update pedido set nro_matricula = 'MA20190629', nro_bl='BQEGCLS196043' where nro_pedido = '279-19';
# update pedido set nro_matricula = 'MA20200126', nro_bl='HLCULIV200158284' where nro_pedido = '051-20';
# update pedido set nro_matricula = 'MA20190553', nro_bl='BQEGARM060656' where nro_pedido = '325-19';
# update pedido set nro_matricula = 'MA20190563', nro_bl='HLCULIV190858274' where nro_pedido = '328-19';
# update pedido set nro_matricula = 'MA20200143', nro_bl='HLCULIV200110612' where nro_pedido = '015-20';
# update pedido set nro_matricula = 'MA20200357', nro_bl='HLCULIV200514777' where nro_pedido = '106-20';
# update pedido set nro_matricula = 'MA20190471', nro_bl='BQEGCLS192756' where nro_pedido = '209-19';
# update pedido set nro_matricula = 'MA20190556', nro_bl='BQEGARM060658' where nro_pedido = '324-19';
# update pedido set nro_matricula = 'MA20200228', nro_bl='HLCULIV200313450' where nro_pedido = '077-20';
# update pedido set nro_matricula = 'MA20200347', nro_bl='HAVFE200760' where nro_pedido = '093-20 109-20';
# update pedido set nro_matricula = 'MA20190682', nro_bl='10-1910-0981' where nro_pedido = '306-19';
# update pedido set nro_matricula = 'MA20190446', nro_bl='HLCULIV190753323' where nro_pedido = '178-19';
# update pedido set nro_matricula = 'MA20190452', nro_bl='HLCULIV190753407' where nro_pedido = '176-19';
# update pedido set nro_matricula = 'MA20200176', nro_bl='HLCULIV200311706' where nro_pedido = '065-20';
# update pedido set nro_matricula = 'MA20190579', nro_bl='10-1909-0945' where nro_pedido = '311-19';
# update pedido set nro_matricula = 'MA20200186', nro_bl='HLCULIV200311688' where nro_pedido = '068-20';
# update pedido set nro_matricula = 'MA20190650', nro_bl='0051370' where nro_pedido = '315-19';
# update pedido set nro_matricula = 'MA20200105', nro_bl='HLCULIV200125689' where nro_pedido = '023-20';
# update pedido set nro_matricula = 'MA20200109', nro_bl='HLCULIV200145224' where nro_pedido = '001-20';
# update pedido set nro_matricula = 'MA20190485', nro_bl='HLCULIV190753283' where nro_pedido = '188-19';
# update pedido set nro_matricula = 'MA20200161', nro_bl='HLCULIV200231744' where nro_pedido = '037-20';
# update pedido set nro_matricula = 'MA20190546', nro_bl='BQEGCLS194397' where nro_pedido = '265-19';
# update pedido set nro_matricula = 'MA20200128', nro_bl='HLCULIV200330326' where nro_pedido = '055-20';
# update pedido set nro_matricula = 'MA20190668', nro_bl='BQEGCLS196474' where nro_pedido = '278-19';
# update pedido set nro_matricula = 'MA20190568', nro_bl='0050927' where nro_pedido = '317-19';
# update pedido set nro_matricula = 'MA20200119', nro_bl='HLCULIV200158262' where nro_pedido = '052-20';
# update pedido set nro_matricula = 'MA20200132', nro_bl='HLCULIV200128621' where nro_pedido = '043-20';
# update pedido set nro_matricula = 'MA20190658', nro_bl='0051371' where nro_pedido = '318-19';
# update pedido set nro_matricula = 'MA20190705', nro_bl='BQEGCLS197503' where nro_pedido = '364-19';
# update pedido set nro_matricula = 'MA20200174', nro_bl='HLCULIV200313226' where nro_pedido = '081-20';
# update pedido set nro_matricula = 'MA20190575', nro_bl='HLCULIV190924378' where nro_pedido = '333-19';
# update pedido set nro_matricula = 'MA20190618', nro_bl='BQEGCLS196048' where nro_pedido = '358-19';
# update pedido set nro_matricula = 'MA20200142', nro_bl='HLCULIV200128811' where nro_pedido = '031-20';
# update pedido set nro_matricula = 'MA20190466', nro_bl='BQEGCLS192767' where nro_pedido = '286-19';
# update pedido set nro_matricula = 'MA20190442', nro_bl='HLCULIV190753390' where nro_pedido = '192-19';
# update pedido set nro_matricula = 'MA20200092', nro_bl='HLCULIV200110276' where nro_pedido = '010-20';
# update pedido set nro_matricula = 'MA20200146', nro_bl='HLCULIV200128716' where nro_pedido = '038-20';
# update pedido set nro_matricula = 'MA20190627', nro_bl='BQEGCLS196047' where nro_pedido = '355-19';
# update pedido set nro_matricula = 'MA20200090', nro_bl='HLCULIV200125528' where nro_pedido = '019-20';
# update pedido set nro_matricula = 'MA20190487', nro_bl='HLCULIV190753389' where nro_pedido = '190-19';
# update pedido set nro_matricula = 'MA20190641', nro_bl='BQEGCLS195285' where nro_pedido = '353-19';
# update pedido set nro_matricula = 'MA20200037', nro_bl='1519488' where nro_pedido = '313-19';
# update pedido set nro_matricula = 'MA20200201', nro_bl='HLCULIV200311297' where nro_pedido = '083-20';
# update pedido set nro_matricula = 'MA20200273', nro_bl='HLCULIV200400888' where nro_pedido = '059-20';
# update pedido set nro_matricula = 'MA20200124', nro_bl='HLCULIV200251049' where nro_pedido = '029-20';
# update pedido set nro_matricula = 'MA20200205', nro_bl='HLCULIV200322749' where nro_pedido = '072-20';
# update pedido set nro_matricula = 'MA20200067', nro_bl='HLCULIV200110221' where nro_pedido = '006-20';
# update pedido set nro_matricula = 'MA20200387', nro_bl='SUDUROLEH005250X' where nro_pedido = '107-20';
# update pedido set nro_matricula = 'MA20200093', nro_bl='HLCULIV200125561' where nro_pedido = '022-20';
# update pedido set nro_matricula = 'MA20190543', nro_bl='BQEGCLS194401' where nro_pedido = '297-19';
# update pedido set nro_matricula = 'MA20200390', nro_bl='HLCULIV200538006' where nro_pedido = '103-20';
# update pedido set nro_matricula = 'MA20190548', nro_bl='BQEGCLS194364' where nro_pedido = '260-19';
# update pedido set nro_matricula = 'MA20200153', nro_bl='HLCULIV200249519' where nro_pedido = '030-20';
# update pedido set nro_matricula = 'MA20200272', nro_bl='HLCULIV200414779' where nro_pedido = '091-20';
# update pedido set nro_matricula = 'MA20200203', nro_bl='HLCULIV200311699' where nro_pedido = '075-20';
# update pedido set nro_matricula = 'MA20200131', nro_bl='HLCULIV200128581' where nro_pedido = '044-20';
